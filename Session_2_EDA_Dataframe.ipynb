# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path=r"C:\Users\Starv\Downloads\Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %%
file_path = r"C:\Users\Starv\Downloads\bank.csv"

visa_df = pd.read_csv(file_path, sep=';')

# %% [markdown]
# - shape
# - size
# - len
# - columns
# - dtypes
# - isnull
# - head
# - tail
# - info

# %%
visa_df.shape
# Out:
# (4521, 17)

# %%
print('the number of rows are:',visa_df.shape[0])
print('the number of rows are:',visa_df.shape[1])
# Out:
# the number of rows are: 4521
# the number of rows are: 17

# %%
visa_df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
len(visa_df.columns)
# Out:
# 17

# %%
visa_df.size
# Out:
# 76857

# %%
len(visa_df)
# Out:
# 4521

# %%
visa_df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
visa_df.tail()
# Out:
#       age            job  marital  education default  balance housing loan  \
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no

# %%
visa_df.isnull()
# Out:
#         age    job  marital  education  default  balance  housing   loan  \
# 0     False  False    False      False    False    False    False  False
# 1     False  False    False      False    False    False    False  False
# 2     False  False    False      False    False    False    False  False
# 3     False  False    False      False    False    False    False  False
# 4     False  False    False      False    False    False    False  False
# ...     ...    ...      ...        ...      ...      ...      ...    ...
# 4516  False  False    False      False    False    False    False  False
# 4517  False  False    False      False    False    False    False  False
# 4518  False  False    False      False    False    False    False  False
# 4519  False  False    False      False    False    False    False  False
# 4520  False  False    False      False    False    False    False  False
#
#       contact    day  month  duration  campaign  pdays  previous  poutcome  \
# 0       False  False  False     False     False  False     False     False
# 1       False  False  False     False     False  False     False     False
# 2       False  False  False     False     False  False     False     False
# 3       False  False  False     False     False  False     False     False
# 4       False  False  False     False     False  False     False     False
# ...       ...    ...    ...       ...       ...    ...       ...       ...
# 4516    False  False  False     False     False  False     False     False
# 4517    False  False  False     False     False  False     False     False
# 4518    False  False  False     False     False  False     False     False
# 4519    False  False  False     False     False  False     False     False
# 4520    False  False  False     False     False  False     False     False
#
#           y
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# ...     ...
# 4516  False
# 4517  False
# 4518  False
# 4519  False
# 4520  False
#
# [4521 rows x 17 columns]

# %%
visa_df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
visa_df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
type(visa_df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(visa_df.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# **task-1**
# - I want to seperate categorical and numerical columns
# - categorical columns in one list
# - numerical columns in another list

# %%
visa_df.dtypes.keys()
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
visa_df.dtypes.values
# Out:
# array([dtype('int64'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('int64'), dtype('O'), dtype('O'), dtype('O'), dtype('int64'),
#        dtype('O'), dtype('int64'), dtype('int64'), dtype('int64'),
#        dtype('int64'), dtype('O'), dtype('O')], dtype=object)

# %%
visa_df.dtypes.keys().tolist()
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'balance',
#  'housing',
#  'loan',
#  'contact',
#  'day',
#  'month',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'y']

# %%
visa_df.dtypes.values.tolist()
# Out:
# [dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('O')]

# %% [markdown]
# **series to list extract**

# %%
visa_df
visa_df.dtypes
visa_df.dtypes.keys()
visa_df.dtypes.values
visa_df.dtypes.keys().tolist()
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'balance',
#  'housing',
#  'loan',
#  'contact',
#  'day',
#  'month',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'y']

# %%
cat=[]
for i,j in zip(dtype,cols):
    if i=='object':
        cat.append(j)
cat=[j for i,j in zip(dtype,cols) if i=='object']
num=[j for i,j in zip(dtype,cols) if i!='object']
len(cat),len(num)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 2
#       1 cat=[]
# ----> 2 for i,j in zip(dtype,cols):
#       3     if i=='object':
#       4         cat.append(j)
#
# NameError: name 'dtype' is not defined

# %%
dtype = visa_df.dtypes        # get datatype of each column
cols = visa_df.columns        # get all column names  correct way

cat = [col for col, t in zip(cols, dtype) if t == 'object']
num = [col for col, t in zip(cols, dtype) if t != 'object']

len(cat), len(num)
# Out:
# (10, 7)

# %%
a=['apple','banana','cherry']
b=[2,3,4]
for i,j in zip(a,b):
    if j%2==0:
        print(i)
# Out:
# apple
# cherry

# %%
visa_df
visa_df.dtypes
visa_df.dtypes.keys()
cols=visa_df.dtypes.keys().tolist()
dtype=visa_df.dtypes.values.tolist()
cat=[j for i,j in zip(dtype,cols) if i=='object']
num=[j for i,j in zip(dtype,cols) if i!='object']
len(cat),len(num)
# Out:
# (10, 7)

# %% [markdown]
# **select dtypes**

# %%
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %% [markdown]
# **task-2:convert series to dataframe**

# %%
dtypes=visa_df.dtypes
d1=pd.DataFrame(dtypes,columns=['Data type'])
d1.reset_index().rename(columns={'index':'Column'})
# Out:
#        Column Data type
# 0         age     int64
# 1         job    object
# 2     marital    object
# 3   education    object
# 4     default    object
# 5     balance     int64
# 6     housing    object
# 7        loan    object
# 8     contact    object
# 9         day     int64
# 10      month    object
# 11   duration     int64
# 12   campaign     int64
# 13      pdays     int64
# 14   previous     int64
# 15   poutcome    object
# 16          y    object

# %%
visa_df.dtypes.keys()
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
visa_df.dtypes.index
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
dict(visa_df.dtypes)
# Out:
# {'age': dtype('int64'),
#  'job': dtype('O'),
#  'marital': dtype('O'),
#  'education': dtype('O'),
#  'default': dtype('O'),
#  'balance': dtype('int64'),
#  'housing': dtype('O'),
#  'loan': dtype('O'),
#  'contact': dtype('O'),
#  'day': dtype('int64'),
#  'month': dtype('O'),
#  'duration': dtype('int64'),
#  'campaign': dtype('int64'),
#  'pdays': dtype('int64'),
#  'previous': dtype('int64'),
#  'poutcome': dtype('O'),
#  'y': dtype('O')}

# %%
# if i have a two list can i create
cols=visa_df.dtypes.index.tolist()
dtype==visa_df.dtypes.values.tolist()
pd.DataFrame(zip(cols,dtype))
# Out:
#             0       1
# 0         age   int64
# 1         job  object
# 2     marital  object
# 3   education  object
# 4     default  object
# 5     balance   int64
# 6     housing  object
# 7        loan  object
# 8     contact  object
# 9         day   int64
# 10      month  object
# 11   duration   int64
# 12   campaign   int64
# 13      pdays   int64
# 14   previous   int64
# 15   poutcome  object
# 16          y  object

# %% [markdown]
# **selection of data**

# %%
visa_df.iloc[rows,columns]
visa_df.iloc[s:s:s,s:s:s]

# %%
visa_df
# 100:105 rows  100,101,102,103,104
# 3:6            3,4,5,
visa_df.iloc[100:105,3:6]

# %%
visa_df.iloc[100:105,3:6] # 100 to 104 rows from 3 to 5 columns
visa_df.iloc[100:105] # 100 to 104 rows from all columns
visa_df.iloc[100] # 100th rows series
visa_df.iloc[[100]] # 100th row df
visa_df.iloc[[100,200,300]]
visa_df.iloc[[100,200,300],3:6] # only 3,6 
visa_df.iloc[[100,200,300],[1,5,9]]
# Out:
#              job  balance  day
# 100  blue-collar        0    6
# 200   technician      992    4
# 300      retired     4531   18

# %%
cols.index('education')
# Out:
# 3

# %%
cols
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'balance',
#  'housing',
#  'loan',
#  'contact',
#  'day',
#  'month',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'y']

# %%
# visa_df.loc[100:105,3:6] # 100 to 104 rows from 3 to 5 columns
# visa_df.loc[100:105] # 100 to 104 rows from all columns
# visa_df.loc[100] # 100th rows series
# visa_df.loc[[100]] # 100th row df
# visa_df.loc[[100,200,300]]
# visa_df.loc[[100,200,300],3:6] # only 3,6 
visa_df.loc[[100,200,300],
          ['duration','balance','education']]
# Out:
#      duration  balance  education
# 100       337        0  secondary
# 200       301      992   tertiary
# 300       445     4531    primary
